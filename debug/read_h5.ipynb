# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
h5_path = "../outputs/collect/All/Level1_pick/dataset/episode_0000.h5"
h5_path = "../outputs/collect/active_vision/dataset/episode_0000.h5"
h5_file = h5py.File(h5_path, 'r')
keys = list(h5_file.keys())
print(f"Keys: {keys}")
for k in keys:
    print(f"key: {k}, value shape: {h5_file[k].shape}")
# Out:
# Keys: ['actions', 'agent_pose', 'ext_camera_2_rgb', 'obs_wrist_camera_rgb', 'op_camera_rgb']
# key: actions, value shape: (1098, 19)
# key: agent_pose, value shape: (1098, 19)
# key: ext_camera_2_rgb, value shape: (1098, 3, 256, 256)
# key: obs_wrist_camera_rgb, value shape: (1098, 3, 256, 256)
# key: op_camera_rgb, value shape: (1098, 3, 256, 256)

# %%
actions = h5_file["actions"][:]
print("actions shape:", actions.shape)
print("actions mean:", actions.mean())
print("actions std:", actions.std())
print("actions min/max:", actions.min(), actions.max())
print(f"action example: {actions[100]}")

poses = h5_file["agent_pose"][:]
print("actions:", actions.shape, actions.mean(), actions.std())
print("poses:", poses.shape, poses.mean(), poses.std())
# Out:
# actions shape: (1098, 19)
# actions mean: 0.22301604
# actions std: 0.8044563
# actions min/max: -1.261234 2.8799899
# action example: [-2.4197621e-03 -8.1425890e-02 -1.3053817e-02 -9.0836659e-02
#   2.9319327e-03  8.8968694e-02  1.3457839e-01  3.9995831e-02
#   3.4416994e-06 -3.0609436e-07 -1.3042203e-06  7.5926853e-04
#   4.1047564e-01 -2.5377806e-02 -8.2740402e-01  8.4232679e-03
#   1.9793034e+00  9.5510352e-01  3.9999999e-02]
# actions: (1098, 19) 0.22301604 0.8044563
# poses: (1098, 19) 0.22289398 0.80411094

# %%
plt.figure()
for i in range(actions.shape[1]):
    plt.plot(actions[:, i], label=f"dim {i}")
plt.legend()
plt.title("Action trajectory")
plt.show()

# %%
img = h5_file["camera_1_rgb"][0]
img = img.transpose(1, 2, 0)
plt.imshow(img)
plt.title("camera_1_rgb frame 0")
plt.show()
